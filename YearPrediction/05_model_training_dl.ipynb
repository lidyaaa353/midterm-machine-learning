# %% [markdown]
# # 05 - Deep Learning Model Training
# ## Year Prediction from Audio Features
#
# ### Models to Train:
# 1. Simple Neural Network (MLP)
# 2. Deep Neural Network
# 3. Neural Network with Regularization
# 4. Residual Network Architecture

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import time
import json

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers, callbacks
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import warnings
warnings.filterwarnings('ignore')

np.random.seed(42)
tf.random.set_seed(42)

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU available: {len(tf.config.list_physical_devices('GPU')) > 0}")

# %% [markdown]
# ## 1. Load Data

# %%
X_train = np.load('data/splits/X_train.npy')
X_val = np.load('data/splits/X_val.npy')
X_test = np.load('data/splits/X_test.npy')

y_train = np.load('data/splits/y_train.npy')
y_val = np.load('data/splits/y_val.npy')
y_test = np.load('data/splits/y_test.npy')

print(f"Training set: {X_train.shape}")
print(f"Validation set: {X_val.shape}")
print(f"Test set: {X_test.shape}")

input_dim = X_train.shape[1]
print(f"\nInput dimension: {input_dim}")
# Out:
# Training set: (394074, 90)
# Validation set: (69543, 90)
# Test set: (51514, 90)
#
# Input dimension: 90

# %% [markdown]
# ## 2. Helper Functions

# %%
def evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test):
    """Evaluate model on all datasets."""
    results = {}
    
    for name, X, y in [('train', X_train, y_train), ('val', X_val, y_val), ('test', X_test, y_test)]:
        y_pred = model.predict(X, verbose=0).flatten()
        results[f'{name}_mse'] = mean_squared_error(y, y_pred)
        results[f'{name}_rmse'] = np.sqrt(results[f'{name}_mse'])
        results[f'{name}_mae'] = mean_absolute_error(y, y_pred)
        results[f'{name}_r2'] = r2_score(y, y_pred)
    
    return results

def print_results(results, model_name):
    """Print formatted results."""
    print(f"\n{'='*60}")
    print(f"{model_name} Results")
    print(f"{'='*60}")
    print(f"{'Set':<10} {'MSE':<12} {'RMSE':<10} {'MAE':<10} {'R²':<10}")
    print("-" * 60)
    for set_name in ['train', 'val', 'test']:
        print(f"{set_name.capitalize():<10} {results[f'{set_name}_mse']:<12.4f} {results[f'{set_name}_rmse']:<10.4f} {results[f'{set_name}_mae']:<10.4f} {results[f'{set_name}_r2']:<10.4f}")

def plot_training_history(history, model_name):
    """Plot training history."""
    fig = make_subplots(rows=1, cols=2, subplot_titles=['Loss', 'MAE'])
    
    fig.add_trace(
        go.Scatter(y=history.history['loss'], name='Train Loss', mode='lines'),
        row=1, col=1
    )
    fig.add_trace(
        go.Scatter(y=history.history['val_loss'], name='Val Loss', mode='lines'),
        row=1, col=1
    )
    
    fig.add_trace(
        go.Scatter(y=history.history['mae'], name='Train MAE', mode='lines'),
        row=1, col=2
    )
    fig.add_trace(
        go.Scatter(y=history.history['val_mae'], name='Val MAE', mode='lines'),
        row=1, col=2
    )
    
    fig.update_layout(title=f'{model_name} - Training History', template='plotly_white', height=400)
    return fig

# %%
all_results = {}

# %% [markdown]
# ## 3. Callbacks Setup

# %%
def get_callbacks(model_name, patience=15):
    """Get standard callbacks for training."""
    return [
        EarlyStopping(
            monitor='val_loss',
            patience=patience,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=1e-6,
            verbose=1
        ),
        ModelCheckpoint(
            f'models/dl/{model_name}_best.keras',
            monitor='val_loss',
            save_best_only=True,
            verbose=0
        )
    ]

# %% [markdown]
# ## 4. Model 1: Simple MLP

# %%
def build_simple_mlp(input_dim):
    model = Sequential([
        Dense(128, activation='relu', input_dim=input_dim),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1)
    ])
    
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='mse',
        metrics=['mae']
    )
    return model

simple_mlp = build_simple_mlp(input_dim)
simple_mlp.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │        11,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,017 (86.00 KB)
#  Trainable params: 22,017 (86.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("Training Simple MLP...")
start_time = time.time()

history_simple = simple_mlp.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=256,
    callbacks=get_callbacks('simple_mlp'),
    verbose=1
)

train_time = time.time() - start_time
results_simple = evaluate_model(simple_mlp, X_train, y_train, X_val, y_val, X_test, y_test)
results_simple['train_time'] = train_time
results_simple['epochs'] = len(history_simple.history['loss'])

print_results(results_simple, "Simple MLP")
all_results['Simple MLP'] = results_simple

fig = plot_training_history(history_simple, "Simple MLP")
fig.write_html('reports/figures/25_simple_mlp_training.html')
fig.show()
# Out:
# Training Simple MLP...
# Epoch 1/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 325381.6250 - mae: 340.7682 - val_loss: 16370.0186 - val_mae: 95.4515 - learning_rate: 0.0010
# Epoch 2/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2775.1821 - mae: 30.5456 - val_loss: 318.2063 - val_mae: 12.9001 - learning_rate: 0.0010
# Epoch 3/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 190.8214 - mae: 9.7397 - val_loss: 133.5341 - val_mae: 8.3127 - learning_rate: 0.0010
# Epoch 4/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 131.3513 - mae: 8.3961 - val_loss: 121.9742 - val_mae: 7.9726 - learning_rate: 0.0010
# Epoch 5/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 128.3538 - mae: 8.3886 - val_loss: 121.2061 - val_mae: 8.0464 - learning_rate: 0.0010
# Epoch 6/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 127.7493 - mae: 8.4142 - val_loss: 119.6438 - val_mae: 8.2964 - learning_rate: 0.0010
# Epoch 7/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 125.1272 - mae: 8.3321 - val_loss: 115.9043 - val_mae: 8.2113 - learning_rate: 0.0010
# Epoch 8/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 122.7256 - mae: 8.2560 - val_loss: 113.1237 - val_mae: 8.1146 - learning_rate: 0.0010
# Epoch 9/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 120.6395 - mae: 8.1842 - val_loss: 110.4883 - val_mae: 7.9732 - learning_rate: 0.0010
# Epoch 10/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 118.6563 - mae: 8.1128 - val_loss: 108.1330 - val_mae: 7.8080 - learning_rate: 0.0010
# Epoch 11/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 116.9118 - mae: 8.0514 - val_loss: 105.7727 - val_mae: 7.5947 - learning_rate: 0.0010
# Epoch 12/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 115.3368 - mae: 7.9926 - val_loss: 104.9998 - val_mae: 7.5420 - learning_rate: 0.0010
# Epoch 13/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 113.9356 - mae: 7.9406 - val_loss: 103.9291 - val_mae: 7.5003 - learning_rate: 0.0010
# Epoch 14/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 112.9211 - mae: 7.9009 - val_loss: 104.0783 - val_mae: 7.4835 - learning_rate: 0.0010
# Epoch 15/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 111.7360 - mae: 7.8539 - val_loss: 103.2882 - val_mae: 7.5009 - learning_rate: 0.0010
# Epoch 16/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 110.8851 - mae: 7.8213 - val_loss: 102.5528 - val_mae: 7.4475 - learning_rate: 0.0010
# Epoch 17/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 109.9656 - mae: 7.7833 - val_loss: 101.6865 - val_mae: 7.4216 - learning_rate: 0.0010
# Epoch 18/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 109.2260 - mae: 7.7545 - val_loss: 102.5373 - val_mae: 7.4716 - learning_rate: 0.0010
# Epoch 19/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 108.5865 - mae: 7.7293 - val_loss: 101.9899 - val_mae: 7.4318 - learning_rate: 0.0010
# Epoch 20/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 108.2267 - mae: 7.7148 - val_loss: 101.9588 - val_mae: 7.4105 - learning_rate: 0.0010
# Epoch 21/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 107.8291 - mae: 7.6989 - val_loss: 101.8304 - val_mae: 7.3881 - learning_rate: 0.0010
# Epoch 22/100
# 1523/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 108.4665 - mae: 7.7274
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 107.2561 - mae: 7.6753 - val_loss: 102.2518 - val_mae: 7.4040 - learning_rate: 0.0010
# Epoch 23/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 88.7893 - mae: 6.8433 - val_loss: 89.2120 - val_mae: 6.6882 - learning_rate: 5.0000e-04
# Epoch 24/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 89.9549 - mae: 6.9038 - val_loss: 89.3929 - val_mae: 6.6579 - learning_rate: 5.0000e-04
# Epoch 25/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 89.7339 - mae: 6.8960 - val_loss: 89.3684 - val_mae: 6.6581 - learning_rate: 5.0000e-04
# Epoch 26/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 89.4400 - mae: 6.8844 - val_loss: 89.2054 - val_mae: 6.6531 - learning_rate: 5.0000e-04
# Epoch 27/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 89.1476 - mae: 6.8726 - val_loss: 89.0702 - val_mae: 6.6538 - learning_rate: 5.0000e-04
# Epoch 28/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 88.9155 - mae: 6.8631 - val_loss: 88.8063 - val_mae: 6.6420 - learning_rate: 5.0000e-04
# Epoch 29/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 88.6706 - mae: 6.8527 - val_loss: 88.7642 - val_mae: 6.6409 - learning_rate: 5.0000e-04
# Epoch 30/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 88.4660 - mae: 6.8449 - val_loss: 89.1756 - val_mae: 6.6607 - learning_rate: 5.0000e-04
# Epoch 31/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 88.2696 - mae: 6.8370 - val_loss: 89.1721 - val_mae: 6.6557 - learning_rate: 5.0000e-04
# Epoch 32/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 88.1033 - mae: 6.8304 - val_loss: 89.1856 - val_mae: 6.6650 - learning_rate: 5.0000e-04
# Epoch 33/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 87.8767 - mae: 6.8211 - val_loss: 89.0323 - val_mae: 6.6572 - learning_rate: 5.0000e-04
# Epoch 34/100
# 1530/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 86.8961 - mae: 6.7741
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 87.6928 - mae: 6.8139 - val_loss: 89.0591 - val_mae: 6.6618 - learning_rate: 5.0000e-04
# Epoch 35/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 79.8820 - mae: 6.3989 - val_loss: 85.4902 - val_mae: 6.6161 - learning_rate: 2.5000e-04
# Epoch 36/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 80.2593 - mae: 6.4261 - val_loss: 85.6112 - val_mae: 6.6125 - learning_rate: 2.5000e-04
# Epoch 37/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 80.2035 - mae: 6.4255 - val_loss: 85.6608 - val_mae: 6.6096 - learning_rate: 2.5000e-04
# Epoch 38/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 80.0891 - mae: 6.4206 - val_loss: 85.7467 - val_mae: 6.6135 - learning_rate: 2.5000e-04
# Epoch 39/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 79.9708 - mae: 6.4157 - val_loss: 85.7697 - val_mae: 6.6138 - learning_rate: 2.5000e-04
# Epoch 40/100
# 1531/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 79.6250 - mae: 6.3961
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 79.8679 - mae: 6.4114 - val_loss: 85.7811 - val_mae: 6.6159 - learning_rate: 2.5000e-04
# Epoch 41/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 75.1889 - mae: 6.1360 - val_loss: 80.6827 - val_mae: 6.3471 - learning_rate: 1.2500e-04
# Epoch 42/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 75.3876 - mae: 6.1506 - val_loss: 80.8327 - val_mae: 6.3502 - learning_rate: 1.2500e-04
# Epoch 43/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 75.3677 - mae: 6.1507 - val_loss: 80.8514 - val_mae: 6.3508 - learning_rate: 1.2500e-04
# Epoch 44/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 75.3098 - mae: 6.1483 - val_loss: 80.8500 - val_mae: 6.3501 - learning_rate: 1.2500e-04
# Epoch 45/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 75.2499 - mae: 6.1456 - val_loss: 80.8402 - val_mae: 6.3482 - learning_rate: 1.2500e-04
# Epoch 46/100
# 1530/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 75.0676 - mae: 6.1391
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 75.1944 - mae: 6.1432 - val_loss: 80.8386 - val_mae: 6.3470 - learning_rate: 1.2500e-04
# Epoch 47/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 72.9011 - mae: 6.0064 - val_loss: 78.4477 - val_mae: 6.1525 - learning_rate: 6.2500e-05
# Epoch 48/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 72.9281 - mae: 6.0092 - val_loss: 78.5102 - val_mae: 6.1436 - learning_rate: 6.2500e-05
# Epoch 49/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 72.9085 - mae: 6.0088 - val_loss: 78.5256 - val_mae: 6.1422 - learning_rate: 6.2500e-05
# Epoch 50/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 72.8785 - mae: 6.0075 - val_loss: 78.5305 - val_mae: 6.1416 - learning_rate: 6.2500e-05
# Epoch 51/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 72.8472 - mae: 6.0061 - val_loss: 78.5280 - val_mae: 6.1409 - learning_rate: 6.2500e-05
# Epoch 52/100
# 1518/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 72.6519 - mae: 5.9970
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 72.8173 - mae: 6.0048 - val_loss: 78.5259 - val_mae: 6.1402 - learning_rate: 6.2500e-05
# Epoch 53/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 71.6637 - mae: 5.9343 - val_loss: 77.6995 - val_mae: 6.1150 - learning_rate: 3.1250e-05
# Epoch 54/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 71.6613 - mae: 5.9350 - val_loss: 77.7032 - val_mae: 6.1168 - learning_rate: 3.1250e-05
# Epoch 55/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 71.6482 - mae: 5.9346 - val_loss: 77.7050 - val_mae: 6.1168 - learning_rate: 3.1250e-05
# Epoch 56/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 71.6326 - mae: 5.9339 - val_loss: 77.7013 - val_mae: 6.1162 - learning_rate: 3.1250e-05
# Epoch 57/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 71.6169 - mae: 5.9332 - val_loss: 77.7031 - val_mae: 6.1161 - learning_rate: 3.1250e-05
# Epoch 58/100
# 1536/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 71.4418 - mae: 5.9259
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 71.6013 - mae: 5.9325 - val_loss: 77.7019 - val_mae: 6.1158 - learning_rate: 3.1250e-05
# Epoch 59/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 70.9858 - mae: 5.8941 - val_loss: 77.2790 - val_mae: 6.0916 - learning_rate: 1.5625e-05
# Epoch 60/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.9725 - mae: 5.8936 - val_loss: 77.2818 - val_mae: 6.0883 - learning_rate: 1.5625e-05
# Epoch 61/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.9647 - mae: 5.8934 - val_loss: 77.2807 - val_mae: 6.0876 - learning_rate: 1.5625e-05
# Epoch 62/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.9565 - mae: 5.8930 - val_loss: 77.2837 - val_mae: 6.0874 - learning_rate: 1.5625e-05
# Epoch 63/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.9481 - mae: 5.8926 - val_loss: 77.2828 - val_mae: 6.0872 - learning_rate: 1.5625e-05
# Epoch 64/100
# 1529/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 70.8381 - mae: 5.8909
# Epoch 64: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 70.9402 - mae: 5.8923 - val_loss: 77.2848 - val_mae: 6.0872 - learning_rate: 1.5625e-05
# Epoch 65/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 70.6153 - mae: 5.8715 - val_loss: 77.2036 - val_mae: 6.1077 - learning_rate: 7.8125e-06
# Epoch 66/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.6071 - mae: 5.8710 - val_loss: 77.2071 - val_mae: 6.1080 - learning_rate: 7.8125e-06
# Epoch 67/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.6027 - mae: 5.8708 - val_loss: 77.2087 - val_mae: 6.1080 - learning_rate: 7.8125e-06
# Epoch 68/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.5984 - mae: 5.8706 - val_loss: 77.2097 - val_mae: 6.1080 - learning_rate: 7.8125e-06
# Epoch 69/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.5941 - mae: 5.8704 - val_loss: 77.2105 - val_mae: 6.1079 - learning_rate: 7.8125e-06
# Epoch 70/100
# 1539/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 70.4824 - mae: 5.8690
# Epoch 70: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.5899 - mae: 5.8703 - val_loss: 77.2118 - val_mae: 6.1079 - learning_rate: 7.8125e-06
# Epoch 71/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.4209 - mae: 5.8595 - val_loss: 77.0935 - val_mae: 6.0787 - learning_rate: 3.9063e-06
# Epoch 72/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.4147 - mae: 5.8589 - val_loss: 77.0945 - val_mae: 6.0788 - learning_rate: 3.9063e-06
# Epoch 73/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.4120 - mae: 5.8587 - val_loss: 77.0960 - val_mae: 6.0788 - learning_rate: 3.9063e-06
# Epoch 74/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.4098 - mae: 5.8586 - val_loss: 77.0967 - val_mae: 6.0788 - learning_rate: 3.9063e-06
# Epoch 75/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.4076 - mae: 5.8585 - val_loss: 77.0970 - val_mae: 6.0788 - learning_rate: 3.9063e-06
# Epoch 76/100
# 1537/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 70.2894 - mae: 5.8566
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.4056 - mae: 5.8584 - val_loss: 77.0972 - val_mae: 6.0787 - learning_rate: 3.9063e-06
# Epoch 77/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.3164 - mae: 5.8535 - val_loss: 77.0804 - val_mae: 6.0709 - learning_rate: 1.9531e-06
# Epoch 78/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.3128 - mae: 5.8531 - val_loss: 77.0802 - val_mae: 6.0708 - learning_rate: 1.9531e-06
# Epoch 79/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.3115 - mae: 5.8530 - val_loss: 77.0805 - val_mae: 6.0708 - learning_rate: 1.9531e-06
# Epoch 80/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.3102 - mae: 5.8529 - val_loss: 77.0810 - val_mae: 6.0708 - learning_rate: 1.9531e-06
# Epoch 81/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.3091 - mae: 5.8529 - val_loss: 77.0814 - val_mae: 6.0708 - learning_rate: 1.9531e-06
# Epoch 82/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.3081 - mae: 5.8528 - val_loss: 77.0817 - val_mae: 6.0708 - learning_rate: 1.9531e-06
# Epoch 83/100
# 1537/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 70.1934 - mae: 5.8507
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.3069 - mae: 5.8528 - val_loss: 77.0818 - val_mae: 6.0707 - learning_rate: 1.9531e-06
# Epoch 84/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.2609 - mae: 5.8507 - val_loss: 77.0799 - val_mae: 6.0712 - learning_rate: 1.0000e-06
# Epoch 85/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.2583 - mae: 5.8504 - val_loss: 77.0796 - val_mae: 6.0712 - learning_rate: 1.0000e-06
# Epoch 86/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.2575 - mae: 5.8504 - val_loss: 77.0797 - val_mae: 6.0712 - learning_rate: 1.0000e-06
# Epoch 87/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.2569 - mae: 5.8504 - val_loss: 77.0797 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 88/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.2563 - mae: 5.8503 - val_loss: 77.0797 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 89/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 70.2559 - mae: 5.8503 - val_loss: 77.0797 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 90/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 70.2553 - mae: 5.8503 - val_loss: 77.0796 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 91/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.2548 - mae: 5.8502 - val_loss: 77.0797 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 92/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.2543 - mae: 5.8502 - val_loss: 77.0798 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 93/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.2537 - mae: 5.8502 - val_loss: 77.0799 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 94/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.2532 - mae: 5.8502 - val_loss: 77.0800 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 95/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.2527 - mae: 5.8501 - val_loss: 77.0799 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 96/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 70.2521 - mae: 5.8501 - val_loss: 77.0799 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 97/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 70.2516 - mae: 5.8501 - val_loss: 77.0801 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 98/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 70.2511 - mae: 5.8501 - val_loss: 77.0800 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 99/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 70.2505 - mae: 5.8500 - val_loss: 77.0803 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Epoch 100/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 70.2500 - mae: 5.8500 - val_loss: 77.0802 - val_mae: 6.0711 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 90.
#
# ============================================================
# Simple MLP Results
# ============================================================
# Set        MSE          RMSE       MAE        R²
# ------------------------------------------------------------
# Train      70.2093      8.3791     5.8472     0.4136
# Val        77.0797      8.7795     6.0711     0.3576
# Test       75.7974      8.7062     6.0485     0.3525

# %% [markdown]
# ## 5. Model 2: Deep Neural Network with Regularization

# %%
def build_deep_nn(input_dim):
    model = Sequential([
        Dense(256, input_dim=input_dim),
        BatchNormalization(),
        layers.Activation('relu'),
        Dropout(0.3),
        
        Dense(128),
        BatchNormalization(),
        layers.Activation('relu'),
        Dropout(0.3),
        
        Dense(64),
        BatchNormalization(),
        layers.Activation('relu'),
        Dropout(0.2),
        
        Dense(32),
        BatchNormalization(),
        layers.Activation('relu'),
        
        Dense(1)
    ])
    
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='mse',
        metrics=['mae']
    )
    return model

deep_nn = build_deep_nn(input_dim)
deep_nn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 256)            │        23,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,481 (267.50 KB)
#  Trainable params: 67,521 (263.75 KB)
#  Non-trainable params: 960 (3.75 KB)

# %%
print("Training Deep Neural Network...")
start_time = time.time()

history_deep = deep_nn.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=256,
    callbacks=get_callbacks('deep_nn'),
    verbose=1
)

train_time = time.time() - start_time
results_deep = evaluate_model(deep_nn, X_train, y_train, X_val, y_val, X_test, y_test)
results_deep['train_time'] = train_time
results_deep['epochs'] = len(history_deep.history['loss'])

print_results(results_deep, "Deep NN")
all_results['Deep NN'] = results_deep

fig = plot_training_history(history_deep, "Deep NN")
fig.write_html('reports/figures/26_deep_nn_training.html')
fig.show()
# Out:
# Training Deep Neural Network...
# Epoch 1/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 3771271.5000 - mae: 1941.1777 - val_loss: 3368979.2500 - val_mae: 1834.6967 - learning_rate: 0.0010
# Epoch 2/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 2749586.0000 - mae: 1651.8871 - val_loss: 2115802.5000 - val_mae: 1449.5551 - learning_rate: 0.0010
# Epoch 3/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1488617.1250 - mae: 1204.1788 - val_loss: 942163.0625 - val_mae: 959.7411 - learning_rate: 0.0010
# Epoch 4/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 534843.2500 - mae: 705.2209 - val_loss: 230541.5938 - val_mae: 468.3349 - learning_rate: 0.0010
# Epoch 5/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 90440.4062 - mae: 269.3279 - val_loss: 16763.9961 - val_mae: 120.6503 - learning_rate: 0.0010
# Epoch 6/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 6942.9126 - mae: 56.4527 - val_loss: 1174.6804 - val_mae: 19.5909 - learning_rate: 0.0010
# Epoch 7/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 2713.7549 - mae: 28.9614 - val_loss: 432.5887 - val_mae: 13.4592 - learning_rate: 0.0010
# Epoch 8/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 1985.7069 - mae: 24.8975 - val_loss: 284.1279 - val_mae: 12.4578 - learning_rate: 0.0010
# Epoch 9/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 1592.4606 - mae: 23.2798 - val_loss: 268.4808 - val_mae: 11.3637 - learning_rate: 0.0010
# Epoch 10/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 1422.8555 - mae: 22.1018 - val_loss: 309.0609 - val_mae: 15.2646 - learning_rate: 0.0010
# Epoch 11/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 1220.0934 - mae: 20.4087 - val_loss: 210.1495 - val_mae: 9.4252 - learning_rate: 0.0010
# Epoch 12/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 1067.3016 - mae: 18.9900 - val_loss: 159.5788 - val_mae: 8.5809 - learning_rate: 0.0010
# Epoch 13/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 861.5966 - mae: 17.8376 - val_loss: 286.9777 - val_mae: 12.5791 - learning_rate: 0.0010
# Epoch 14/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 692.4793 - mae: 16.2300 - val_loss: 153.1373 - val_mae: 8.6864 - learning_rate: 0.0010
# Epoch 15/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 600.8459 - mae: 15.5819 - val_loss: 171.2175 - val_mae: 8.6909 - learning_rate: 0.0010
# Epoch 16/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 519.7701 - mae: 14.8358 - val_loss: 128.9425 - val_mae: 8.1789 - learning_rate: 0.0010
# Epoch 17/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 472.8254 - mae: 14.2322 - val_loss: 135.9275 - val_mae: 8.4182 - learning_rate: 0.0010
# Epoch 18/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 431.4300 - mae: 13.7064 - val_loss: 162.7702 - val_mae: 10.8135 - learning_rate: 0.0010
# Epoch 19/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 383.1271 - mae: 13.0893 - val_loss: 145.3530 - val_mae: 10.0276 - learning_rate: 0.0010
# Epoch 20/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 346.9269 - mae: 12.6881 - val_loss: 139.5037 - val_mae: 8.6740 - learning_rate: 0.0010
# Epoch 21/100
# 1538/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 341.1887 - mae: 12.5302
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 327.8229 - mae: 12.3125 - val_loss: 174.9726 - val_mae: 11.0700 - learning_rate: 0.0010
# Epoch 22/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 282.7563 - mae: 11.6106 - val_loss: 132.9834 - val_mae: 8.3514 - learning_rate: 5.0000e-04
# Epoch 23/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 276.2308 - mae: 11.4188 - val_loss: 136.4330 - val_mae: 7.9620 - learning_rate: 5.0000e-04
# Epoch 24/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 255.4533 - mae: 11.1431 - val_loss: 130.1386 - val_mae: 8.8428 - learning_rate: 5.0000e-04
# Epoch 25/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 242.5146 - mae: 10.9429 - val_loss: 130.8274 - val_mae: 9.2629 - learning_rate: 5.0000e-04
# Epoch 26/100
# 1533/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 249.6396 - mae: 10.9935
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 240.1071 - mae: 10.8268 - val_loss: 131.0479 - val_mae: 9.0084 - learning_rate: 5.0000e-04
# Epoch 27/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 220.9848 - mae: 10.5389 - val_loss: 122.7952 - val_mae: 8.3591 - learning_rate: 2.5000e-04
# Epoch 28/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 215.6983 - mae: 10.4463 - val_loss: 127.5452 - val_mae: 8.1558 - learning_rate: 2.5000e-04
# Epoch 29/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 207.0385 - mae: 10.2478 - val_loss: 122.8733 - val_mae: 8.6333 - learning_rate: 2.5000e-04
# Epoch 30/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 205.1752 - mae: 10.2114 - val_loss: 132.4385 - val_mae: 8.0708 - learning_rate: 2.5000e-04
# Epoch 31/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 195.8679 - mae: 10.0219 - val_loss: 123.8769 - val_mae: 8.7409 - learning_rate: 2.5000e-04
# Epoch 32/100
# 1539/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 197.3904 - mae: 10.0740
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 196.4633 - mae: 10.0112 - val_loss: 123.9021 - val_mae: 8.2619 - learning_rate: 2.5000e-04
# Epoch 33/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 190.3109 - mae: 9.8596 - val_loss: 122.3553 - val_mae: 8.0850 - learning_rate: 1.2500e-04
# Epoch 34/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 189.1629 - mae: 9.8552 - val_loss: 120.5145 - val_mae: 7.7686 - learning_rate: 1.2500e-04
# Epoch 35/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 184.6284 - mae: 9.7321 - val_loss: 120.9530 - val_mae: 7.9774 - learning_rate: 1.2500e-04
# Epoch 36/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 182.5660 - mae: 9.6966 - val_loss: 120.0779 - val_mae: 8.2598 - learning_rate: 1.2500e-04
# Epoch 37/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 181.7769 - mae: 9.6774 - val_loss: 120.8494 - val_mae: 8.2417 - learning_rate: 1.2500e-04
# Epoch 38/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 180.2733 - mae: 9.6355 - val_loss: 119.3860 - val_mae: 8.1826 - learning_rate: 1.2500e-04
# Epoch 39/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 178.9319 - mae: 9.5867 - val_loss: 124.0726 - val_mae: 7.9489 - learning_rate: 1.2500e-04
# Epoch 40/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 177.7329 - mae: 9.5401 - val_loss: 122.2021 - val_mae: 8.2219 - learning_rate: 1.2500e-04
# Epoch 41/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 175.0231 - mae: 9.4926 - val_loss: 117.7881 - val_mae: 8.2836 - learning_rate: 1.2500e-04
# Epoch 42/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 171.7245 - mae: 9.4206 - val_loss: 118.1460 - val_mae: 8.1075 - learning_rate: 1.2500e-04
# Epoch 43/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 171.8660 - mae: 9.4070 - val_loss: 125.0395 - val_mae: 7.7629 - learning_rate: 1.2500e-04
# Epoch 44/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 170.6451 - mae: 9.3672 - val_loss: 117.4010 - val_mae: 7.8908 - learning_rate: 1.2500e-04
# Epoch 45/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 168.7273 - mae: 9.3320 - val_loss: 119.4158 - val_mae: 7.8974 - learning_rate: 1.2500e-04
# Epoch 46/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 166.9232 - mae: 9.2795 - val_loss: 126.6538 - val_mae: 7.6124 - learning_rate: 1.2500e-04
# Epoch 47/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 166.3689 - mae: 9.2692 - val_loss: 124.4425 - val_mae: 7.6370 - learning_rate: 1.2500e-04
# Epoch 48/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 162.5627 - mae: 9.1883 - val_loss: 119.8507 - val_mae: 8.1256 - learning_rate: 1.2500e-04
# Epoch 49/100
# 1533/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 163.3930 - mae: 9.1699
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 161.5268 - mae: 9.1575 - val_loss: 119.8216 - val_mae: 7.6867 - learning_rate: 1.2500e-04
# Epoch 50/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 160.0446 - mae: 9.1147 - val_loss: 119.9613 - val_mae: 7.7358 - learning_rate: 6.2500e-05
# Epoch 51/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 158.7769 - mae: 9.0656 - val_loss: 120.7150 - val_mae: 7.8779 - learning_rate: 6.2500e-05
# Epoch 52/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 158.9422 - mae: 9.0688 - val_loss: 117.1105 - val_mae: 7.8008 - learning_rate: 6.2500e-05
# Epoch 53/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 157.6755 - mae: 9.0509 - val_loss: 119.7695 - val_mae: 7.6687 - learning_rate: 6.2500e-05
# Epoch 54/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 157.2249 - mae: 9.0383 - val_loss: 120.4422 - val_mae: 7.6208 - learning_rate: 6.2500e-05
# Epoch 55/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 157.3474 - mae: 8.9964 - val_loss: 119.7348 - val_mae: 7.8238 - learning_rate: 6.2500e-05
# Epoch 56/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 154.8103 - mae: 8.9786 - val_loss: 120.3547 - val_mae: 8.0334 - learning_rate: 6.2500e-05
# Epoch 57/100
# 1535/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 152.3977 - mae: 8.9506
# Epoch 57: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 152.9941 - mae: 8.9463 - val_loss: 122.0045 - val_mae: 7.6377 - learning_rate: 6.2500e-05
# Epoch 58/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 153.6063 - mae: 8.9330 - val_loss: 117.6434 - val_mae: 7.7906 - learning_rate: 3.1250e-05
# Epoch 59/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 153.1648 - mae: 8.9123 - val_loss: 116.4242 - val_mae: 7.6617 - learning_rate: 3.1250e-05
# Epoch 60/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 153.8757 - mae: 8.9082 - val_loss: 116.7420 - val_mae: 7.7662 - learning_rate: 3.1250e-05
# Epoch 61/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 152.6600 - mae: 8.8867 - val_loss: 115.0063 - val_mae: 7.6040 - learning_rate: 3.1250e-05
# Epoch 62/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 150.8000 - mae: 8.8549 - val_loss: 117.2408 - val_mae: 7.6296 - learning_rate: 3.1250e-05
# Epoch 63/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 151.5596 - mae: 8.8480 - val_loss: 118.2135 - val_mae: 7.6288 - learning_rate: 3.1250e-05
# Epoch 64/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 152.4767 - mae: 8.8937 - val_loss: 117.6395 - val_mae: 7.5358 - learning_rate: 3.1250e-05
# Epoch 65/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 150.4079 - mae: 8.8429 - val_loss: 116.8235 - val_mae: 7.6465 - learning_rate: 3.1250e-05
# Epoch 66/100
# 1538/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 151.1765 - mae: 8.8666
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 150.6672 - mae: 8.8667 - val_loss: 116.5541 - val_mae: 7.5803 - learning_rate: 3.1250e-05
# Epoch 67/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 149.1762 - mae: 8.8010 - val_loss: 117.2068 - val_mae: 7.6103 - learning_rate: 1.5625e-05
# Epoch 68/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 149.3322 - mae: 8.8179 - val_loss: 116.6982 - val_mae: 7.4942 - learning_rate: 1.5625e-05
# Epoch 69/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 149.0185 - mae: 8.8162 - val_loss: 116.7215 - val_mae: 7.5170 - learning_rate: 1.5625e-05
# Epoch 70/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 148.3104 - mae: 8.7756 - val_loss: 116.8401 - val_mae: 7.4933 - learning_rate: 1.5625e-05
# Epoch 71/100
# 1529/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 146.6099 - mae: 8.7332
# Epoch 71: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 147.6058 - mae: 8.7593 - val_loss: 116.5021 - val_mae: 7.6510 - learning_rate: 1.5625e-05
# Epoch 72/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 148.2654 - mae: 8.7869 - val_loss: 114.8446 - val_mae: 7.4439 - learning_rate: 7.8125e-06
# Epoch 73/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 148.8122 - mae: 8.8019 - val_loss: 117.7902 - val_mae: 7.5473 - learning_rate: 7.8125e-06
# Epoch 74/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 148.5820 - mae: 8.7941 - val_loss: 117.7838 - val_mae: 7.4083 - learning_rate: 7.8125e-06
# Epoch 75/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 147.8105 - mae: 8.7653 - val_loss: 117.2568 - val_mae: 7.4567 - learning_rate: 7.8125e-06
# Epoch 76/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 147.3170 - mae: 8.7730 - val_loss: 116.7337 - val_mae: 7.3851 - learning_rate: 7.8125e-06
# Epoch 77/100
# 1531/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 147.2421 - mae: 8.7626
# Epoch 77: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 147.9262 - mae: 8.7835 - val_loss: 116.9424 - val_mae: 7.4439 - learning_rate: 7.8125e-06
# Epoch 78/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 147.7031 - mae: 8.7800 - val_loss: 118.2630 - val_mae: 7.4971 - learning_rate: 3.9063e-06
# Epoch 79/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 147.5690 - mae: 8.7501 - val_loss: 116.2318 - val_mae: 7.4027 - learning_rate: 3.9063e-06
# Epoch 80/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 147.7549 - mae: 8.7534 - val_loss: 118.1800 - val_mae: 7.4150 - learning_rate: 3.9063e-06
# Epoch 81/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 148.5040 - mae: 8.8010 - val_loss: 117.1146 - val_mae: 7.5362 - learning_rate: 3.9063e-06
# Epoch 82/100
# 1529/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 147.2342 - mae: 8.7460
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 147.4505 - mae: 8.7528 - val_loss: 117.5662 - val_mae: 7.4577 - learning_rate: 3.9063e-06
# Epoch 83/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 148.2101 - mae: 8.7736 - val_loss: 117.9873 - val_mae: 7.4510 - learning_rate: 1.9531e-06
# Epoch 84/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 146.0832 - mae: 8.7198 - val_loss: 116.5294 - val_mae: 7.4829 - learning_rate: 1.9531e-06
# Epoch 85/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 147.1292 - mae: 8.7599 - val_loss: 116.7698 - val_mae: 7.4371 - learning_rate: 1.9531e-06
# Epoch 86/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 146.8532 - mae: 8.7474 - val_loss: 121.5251 - val_mae: 7.5062 - learning_rate: 1.9531e-06
# Epoch 87/100
# 1535/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 146.9039 - mae: 8.7537
# Epoch 87: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 146.1602 - mae: 8.7429 - val_loss: 115.6662 - val_mae: 7.4332 - learning_rate: 1.9531e-06
# Epoch 87: early stopping
# Restoring model weights from the end of the best epoch: 72.
#
# ============================================================
# Deep NN Results
# ============================================================
# Set        MSE          RMSE       MAE        R²
# ------------------------------------------------------------
# Train      109.2295     10.4513    7.4129     0.0877
# Val        114.8446     10.7166    7.4439     0.0429
# Test       106.6371     10.3265    7.3481     0.0891

# %% [markdown]
# ## 6. Model 3: Wide and Deep Network

# %%
def build_wide_deep(input_dim):
    inputs = Input(shape=(input_dim,))
    
    wide = Dense(1)(inputs)
    
    deep = Dense(256, activation='relu')(inputs)
    deep = BatchNormalization()(deep)
    deep = Dropout(0.3)(deep)
    
    deep = Dense(128, activation='relu')(deep)
    deep = BatchNormalization()(deep)
    deep = Dropout(0.3)(deep)
    
    deep = Dense(64, activation='relu')(deep)
    deep = BatchNormalization()(deep)
    deep = Dropout(0.2)(deep)
    
    deep = Dense(1)(deep)
    
    output = Add()([wide, deep])
    
    model = Model(inputs=inputs, outputs=output)
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='mse',
        metrics=['mae']
    )
    return model

wide_deep = build_wide_deep(input_dim)
wide_deep.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 90)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 256)       │     23,296 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 128)       │     32,896 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_11[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 64)        │      8,256 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_12[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1)         │         91 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1)         │         65 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1)         │          0 │ dense_9[0][0],    │
# │                     │                   │            │ dense_13[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 66,396 (259.36 KB)
#  Trainable params: 65,500 (255.86 KB)
#  Non-trainable params: 896 (3.50 KB)

# %%
print("Training Wide and Deep Network...")
start_time = time.time()

history_wide_deep = wide_deep.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=256,
    callbacks=get_callbacks('wide_deep'),
    verbose=1
)

train_time = time.time() - start_time
results_wide_deep = evaluate_model(wide_deep, X_train, y_train, X_val, y_val, X_test, y_test)
results_wide_deep['train_time'] = train_time
results_wide_deep['epochs'] = len(history_wide_deep.history['loss'])

print_results(results_wide_deep, "Wide and Deep")
all_results['Wide and Deep'] = results_wide_deep

fig = plot_training_history(history_wide_deep, "Wide and Deep")
fig.write_html('reports/figures/27_wide_deep_training.html')
fig.show()
# Out:
# Training Wide and Deep Network...
# Epoch 1/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3531553.5000 - mae: 1876.1956 - val_loss: 2723358.0000 - val_mae: 1650.2158 - learning_rate: 0.0010
# Epoch 2/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1726679.5000 - mae: 1295.5132 - val_loss: 835651.1875 - val_mae: 914.0671 - learning_rate: 0.0010
# Epoch 3/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 354006.8438 - mae: 554.0575 - val_loss: 59450.1914 - val_mae: 243.5818 - learning_rate: 0.0010
# Epoch 4/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 27509.2188 - mae: 132.6462 - val_loss: 410.0836 - val_mae: 18.4622 - learning_rate: 0.0010
# Epoch 5/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15701.7871 - mae: 99.9109 - val_loss: 176.9984 - val_mae: 11.6358 - learning_rate: 0.0010
# Epoch 6/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 15678.7676 - mae: 100.0109 - val_loss: 162.1065 - val_mae: 11.1355 - learning_rate: 0.0010
# Epoch 7/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15584.5752 - mae: 99.6774 - val_loss: 177.2544 - val_mae: 11.3569 - learning_rate: 0.0010
# Epoch 8/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15568.2383 - mae: 99.6794 - val_loss: 161.7806 - val_mae: 11.0813 - learning_rate: 0.0010
# Epoch 9/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15452.4375 - mae: 99.2785 - val_loss: 177.6716 - val_mae: 11.7997 - learning_rate: 0.0010
# Epoch 10/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15465.7656 - mae: 99.4119 - val_loss: 167.2038 - val_mae: 11.5198 - learning_rate: 0.0010
# Epoch 11/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15451.6064 - mae: 99.3320 - val_loss: 145.1102 - val_mae: 10.3997 - learning_rate: 0.0010
# Epoch 12/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15435.7266 - mae: 99.2500 - val_loss: 131.7922 - val_mae: 9.7504 - learning_rate: 0.0010
# Epoch 13/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 15383.1396 - mae: 99.0940 - val_loss: 120.6819 - val_mae: 9.1260 - learning_rate: 0.0010
# Epoch 14/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15316.0967 - mae: 98.8232 - val_loss: 149.3402 - val_mae: 10.5801 - learning_rate: 0.0010
# Epoch 15/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 15304.3613 - mae: 98.8614 - val_loss: 131.3744 - val_mae: 9.6680 - learning_rate: 0.0010
# Epoch 16/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15316.5449 - mae: 98.8352 - val_loss: 151.1594 - val_mae: 10.7309 - learning_rate: 0.0010
# Epoch 17/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15194.3799 - mae: 98.5303 - val_loss: 109.4544 - val_mae: 8.5281 - learning_rate: 0.0010
# Epoch 18/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15168.4023 - mae: 98.3647 - val_loss: 163.3755 - val_mae: 11.1209 - learning_rate: 0.0010
# Epoch 19/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 15184.8613 - mae: 98.4396 - val_loss: 135.9023 - val_mae: 10.0897 - learning_rate: 0.0010
# Epoch 20/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15111.0537 - mae: 98.2059 - val_loss: 113.7094 - val_mae: 8.8314 - learning_rate: 0.0010
# Epoch 21/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15095.9521 - mae: 98.1692 - val_loss: 182.3510 - val_mae: 12.0810 - learning_rate: 0.0010
# Epoch 22/100
# 1538/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15029.4745 - mae: 97.9864
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15063.4922 - mae: 98.0819 - val_loss: 140.1279 - val_mae: 10.3068 - learning_rate: 0.0010
# Epoch 23/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15016.2148 - mae: 97.8671 - val_loss: 132.9952 - val_mae: 9.9881 - learning_rate: 5.0000e-04
# Epoch 24/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 14969.3213 - mae: 97.8945 - val_loss: 186.8381 - val_mae: 12.1878 - learning_rate: 5.0000e-04
# Epoch 25/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 15020.3037 - mae: 97.9231 - val_loss: 128.1862 - val_mae: 9.7016 - learning_rate: 5.0000e-04
# Epoch 26/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 14940.2441 - mae: 97.6832 - val_loss: 163.6477 - val_mae: 11.3527 - learning_rate: 5.0000e-04
# Epoch 27/100
# 1533/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14910.4890 - mae: 97.5147
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 14982.5449 - mae: 97.7462 - val_loss: 141.5446 - val_mae: 10.1962 - learning_rate: 5.0000e-04
# Epoch 28/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 14989.4570 - mae: 97.8212 - val_loss: 152.8770 - val_mae: 10.8669 - learning_rate: 2.5000e-04
# Epoch 29/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 14996.3818 - mae: 97.8511 - val_loss: 124.2506 - val_mae: 9.3833 - learning_rate: 2.5000e-04
# Epoch 30/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 14885.9385 - mae: 97.4842 - val_loss: 129.1019 - val_mae: 9.6899 - learning_rate: 2.5000e-04
# Epoch 31/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 14918.3086 - mae: 97.5964 - val_loss: 136.5534 - val_mae: 10.0794 - learning_rate: 2.5000e-04
# Epoch 32/100
# 1538/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14820.9711 - mae: 97.3423
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 14847.3916 - mae: 97.3886 - val_loss: 114.4003 - val_mae: 8.8934 - learning_rate: 2.5000e-04
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 17.
#
# ============================================================
# Wide and Deep Results
# ============================================================
# Set        MSE          RMSE       MAE        R²
# ------------------------------------------------------------
# Train      108.8716     10.4342    8.5160     0.0907
# Val        109.4543     10.4620    8.5281     0.0878
# Test       107.9563     10.3902    8.4986     0.0778

# %% [markdown]
# ## 7. Model 4: Residual Network

# %%
def build_resnet(input_dim):
    inputs = Input(shape=(input_dim,))
    
    x = Dense(128, activation='relu')(inputs)
    x = BatchNormalization()(x)
    
    residual = x
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(128)(x)
    x = Add()([x, residual])
    x = layers.Activation('relu')(x)
    x = BatchNormalization()(x)
    
    residual = x
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(128)(x)
    x = Add()([x, residual])
    x = layers.Activation('relu')(x)
    x = BatchNormalization()(x)
    
    x = Dense(64, activation='relu')(x)
    x = Dense(32, activation='relu')(x)
    output = Dense(1)(x)
    
    model = Model(inputs=inputs, outputs=output)
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='mse',
        metrics=['mae']
    )
    return model

resnet = build_resnet(input_dim)
resnet.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 90)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 128)       │     11,648 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_14[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 128)       │     16,512 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_15[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 128)       │     16,512 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128)       │          0 │ dense_16[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 128)       │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ activation_4[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 128)       │     16,512 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_17[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 128)       │     16,512 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 128)       │          0 │ dense_18[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 128)       │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ activation_5[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 64)        │      8,256 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 32)        │      2,080 │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 1)         │         33 │ dense_20[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 90,625 (354.00 KB)
#  Trainable params: 89,345 (349.00 KB)
#  Non-trainable params: 1,280 (5.00 KB)

# %%
print("Training Residual Network...")
start_time = time.time()

history_resnet = resnet.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=256,
    callbacks=get_callbacks('resnet'),
    verbose=1
)

train_time = time.time() - start_time
results_resnet = evaluate_model(resnet, X_train, y_train, X_val, y_val, X_test, y_test)
results_resnet['train_time'] = train_time
results_resnet['epochs'] = len(history_resnet.history['loss'])

print_results(results_resnet, "ResNet")
all_results['ResNet'] = results_resnet

fig = plot_training_history(history_resnet, "ResNet")
fig.write_html('reports/figures/28_resnet_training.html')
fig.show()
# Out:
# Training Residual Network...
# Epoch 1/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 276204.9062 - mae: 231.1504 - val_loss: 7075.7896 - val_mae: 56.1128 - learning_rate: 0.0010
# Epoch 2/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 6081.7021 - mae: 56.5076 - val_loss: 818.7928 - val_mae: 24.1311 - learning_rate: 0.0010
# Epoch 3/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 2236.2083 - mae: 33.2769 - val_loss: 570.0016 - val_mae: 18.6804 - learning_rate: 0.0010
# Epoch 4/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1007.5009 - mae: 23.3001 - val_loss: 197.0549 - val_mae: 10.0891 - learning_rate: 0.0010
# Epoch 5/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 651.9865 - mae: 19.1978 - val_loss: 356.3009 - val_mae: 13.5139 - learning_rate: 0.0010
# Epoch 6/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 575.3688 - mae: 18.2706 - val_loss: 149.6400 - val_mae: 9.9865 - learning_rate: 0.0010
# Epoch 7/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 469.9086 - mae: 16.6691 - val_loss: 758.7343 - val_mae: 24.8656 - learning_rate: 0.0010
# Epoch 8/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 394.4145 - mae: 15.3079 - val_loss: 357.1962 - val_mae: 16.8363 - learning_rate: 0.0010
# Epoch 9/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 360.0961 - mae: 14.5758 - val_loss: 525.0701 - val_mae: 20.6568 - learning_rate: 0.0010
# Epoch 10/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 321.1098 - mae: 13.6661 - val_loss: 130.2441 - val_mae: 8.1435 - learning_rate: 0.0010
# Epoch 11/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 308.7710 - mae: 13.4742 - val_loss: 240.3146 - val_mae: 13.5794 - learning_rate: 0.0010
# Epoch 12/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 270.1039 - mae: 12.5843 - val_loss: 264.3211 - val_mae: 13.0704 - learning_rate: 0.0010
# Epoch 13/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 246.2948 - mae: 12.0558 - val_loss: 112.3274 - val_mae: 7.1334 - learning_rate: 0.0010
# Epoch 14/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 263.5387 - mae: 12.3904 - val_loss: 159.2909 - val_mae: 9.7492 - learning_rate: 0.0010
# Epoch 15/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 224.5821 - mae: 11.4571 - val_loss: 165.2161 - val_mae: 9.7525 - learning_rate: 0.0010
# Epoch 16/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 216.8992 - mae: 11.2463 - val_loss: 129.4763 - val_mae: 7.9206 - learning_rate: 0.0010
# Epoch 17/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 218.9225 - mae: 11.1609 - val_loss: 210.5780 - val_mae: 10.2633 - learning_rate: 0.0010
# Epoch 18/100
# 1535/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 230.7912 - mae: 11.7078
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 199.9136 - mae: 10.8413 - val_loss: 167.7804 - val_mae: 10.2295 - learning_rate: 0.0010
# Epoch 19/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 146.5761 - mae: 9.0708 - val_loss: 93.0282 - val_mae: 7.0974 - learning_rate: 5.0000e-04
# Epoch 20/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 145.2769 - mae: 9.1048 - val_loss: 99.4972 - val_mae: 6.8857 - learning_rate: 5.0000e-04
# Epoch 21/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 147.6252 - mae: 9.1590 - val_loss: 113.1948 - val_mae: 8.2916 - learning_rate: 5.0000e-04
# Epoch 22/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 145.9371 - mae: 9.1528 - val_loss: 120.5730 - val_mae: 8.8360 - learning_rate: 5.0000e-04
# Epoch 23/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 146.3197 - mae: 9.0270 - val_loss: 106.3758 - val_mae: 7.9152 - learning_rate: 5.0000e-04
# Epoch 24/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 135.5480 - mae: 8.7219 - val_loss: 91.7988 - val_mae: 6.8819 - learning_rate: 5.0000e-04
# Epoch 25/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 135.9117 - mae: 8.8018 - val_loss: 86.1873 - val_mae: 6.7476 - learning_rate: 5.0000e-04
# Epoch 26/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 131.2271 - mae: 8.6057 - val_loss: 87.3928 - val_mae: 6.6361 - learning_rate: 5.0000e-04
# Epoch 27/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 133.4538 - mae: 8.6863 - val_loss: 99.7341 - val_mae: 7.2840 - learning_rate: 5.0000e-04
# Epoch 28/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 127.1667 - mae: 8.4093 - val_loss: 96.6045 - val_mae: 7.5262 - learning_rate: 5.0000e-04
# Epoch 29/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 133.5786 - mae: 8.5976 - val_loss: 227.0596 - val_mae: 13.3010 - learning_rate: 5.0000e-04
# Epoch 30/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 131.2823 - mae: 8.6221
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 126.6433 - mae: 8.4342 - val_loss: 101.3262 - val_mae: 7.4836 - learning_rate: 5.0000e-04
# Epoch 31/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 111.2365 - mae: 7.7736 - val_loss: 98.6407 - val_mae: 7.6019 - learning_rate: 2.5000e-04
# Epoch 32/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 111.9318 - mae: 7.8367 - val_loss: 83.7620 - val_mae: 6.5774 - learning_rate: 2.5000e-04
# Epoch 33/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 112.4354 - mae: 7.8477 - val_loss: 93.6219 - val_mae: 7.3916 - learning_rate: 2.5000e-04
# Epoch 34/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 110.4527 - mae: 7.7529 - val_loss: 87.1794 - val_mae: 6.9227 - learning_rate: 2.5000e-04
# Epoch 35/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 107.9357 - mae: 7.6305 - val_loss: 82.2545 - val_mae: 6.5408 - learning_rate: 2.5000e-04
# Epoch 36/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 109.9230 - mae: 7.7434 - val_loss: 83.3815 - val_mae: 6.5906 - learning_rate: 2.5000e-04
# Epoch 37/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 109.8987 - mae: 7.7261 - val_loss: 100.5194 - val_mae: 6.8860 - learning_rate: 2.5000e-04
# Epoch 38/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 106.2227 - mae: 7.5827 - val_loss: 90.9700 - val_mae: 6.4727 - learning_rate: 2.5000e-04
# Epoch 39/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 105.6527 - mae: 7.5414 - val_loss: 84.8292 - val_mae: 6.7680 - learning_rate: 2.5000e-04
# Epoch 40/100
# 1539/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 107.0730 - mae: 7.6258
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 105.1794 - mae: 7.5249 - val_loss: 84.3201 - val_mae: 6.5574 - learning_rate: 2.5000e-04
# Epoch 41/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 100.2759 - mae: 7.2373 - val_loss: 91.3426 - val_mae: 7.2074 - learning_rate: 1.2500e-04
# Epoch 42/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 99.6203 - mae: 7.2602 - val_loss: 86.5490 - val_mae: 6.6781 - learning_rate: 1.2500e-04
# Epoch 43/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 99.2100 - mae: 7.2126 - val_loss: 82.3419 - val_mae: 6.4340 - learning_rate: 1.2500e-04
# Epoch 44/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 98.2447 - mae: 7.1892 - val_loss: 84.8566 - val_mae: 6.5643 - learning_rate: 1.2500e-04
# Epoch 45/100
# 1538/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 98.6990 - mae: 7.2198
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 98.7188 - mae: 7.2165 - val_loss: 86.2505 - val_mae: 6.3575 - learning_rate: 1.2500e-04
# Epoch 46/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 95.2115 - mae: 7.0537 - val_loss: 81.0539 - val_mae: 6.3384 - learning_rate: 6.2500e-05
# Epoch 47/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 95.2020 - mae: 7.0422 - val_loss: 84.2859 - val_mae: 6.2585 - learning_rate: 6.2500e-05
# Epoch 48/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 94.5160 - mae: 7.0272 - val_loss: 83.0235 - val_mae: 6.5937 - learning_rate: 6.2500e-05
# Epoch 49/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 94.0527 - mae: 7.0064 - val_loss: 84.5518 - val_mae: 6.6677 - learning_rate: 6.2500e-05
# Epoch 50/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 94.8161 - mae: 7.0341 - val_loss: 79.8891 - val_mae: 6.2268 - learning_rate: 6.2500e-05
# Epoch 51/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 93.8805 - mae: 6.9864 - val_loss: 80.6833 - val_mae: 6.1501 - learning_rate: 6.2500e-05
# Epoch 52/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 94.2205 - mae: 7.0068 - val_loss: 83.5247 - val_mae: 6.3477 - learning_rate: 6.2500e-05
# Epoch 53/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 93.8240 - mae: 6.9848 - val_loss: 84.8641 - val_mae: 6.7414 - learning_rate: 6.2500e-05
# Epoch 54/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 93.5035 - mae: 6.9784 - val_loss: 91.2302 - val_mae: 7.1405 - learning_rate: 6.2500e-05
# Epoch 55/100
# 1532/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 93.0694 - mae: 6.9579
# Epoch 55: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 93.1080 - mae: 6.9585 - val_loss: 85.4732 - val_mae: 6.3845 - learning_rate: 6.2500e-05
# Epoch 56/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 91.9706 - mae: 6.8817 - val_loss: 81.9942 - val_mae: 6.3332 - learning_rate: 3.1250e-05
# Epoch 57/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 91.6532 - mae: 6.8860 - val_loss: 80.5907 - val_mae: 6.2613 - learning_rate: 3.1250e-05
# Epoch 58/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 91.8957 - mae: 6.8920 - val_loss: 80.9482 - val_mae: 6.2494 - learning_rate: 3.1250e-05
# Epoch 59/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 91.6175 - mae: 6.8766 - val_loss: 80.7015 - val_mae: 6.2268 - learning_rate: 3.1250e-05
# Epoch 60/100
# 1531/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 91.5294 - mae: 6.8898
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 91.5761 - mae: 6.8859 - val_loss: 80.5378 - val_mae: 6.3315 - learning_rate: 3.1250e-05
# Epoch 61/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 90.4546 - mae: 6.8124 - val_loss: 81.5257 - val_mae: 6.2759 - learning_rate: 1.5625e-05
# Epoch 62/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 92.5823 - mae: 6.8558 - val_loss: 81.3257 - val_mae: 6.2290 - learning_rate: 1.5625e-05
# Epoch 63/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 90.9836 - mae: 6.8282 - val_loss: 80.7967 - val_mae: 6.1565 - learning_rate: 1.5625e-05
# Epoch 64/100
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 90.7613 - mae: 6.8330 - val_loss: 80.9026 - val_mae: 6.0952 - learning_rate: 1.5625e-05
# Epoch 65/100
# 1533/1540 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 91.0783 - mae: 6.8425
# Epoch 65: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1540/1540 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 91.0524 - mae: 6.8385 - val_loss: 81.1313 - val_mae: 6.3696 - learning_rate: 1.5625e-05
# Epoch 65: early stopping
# Restoring model weights from the end of the best epoch: 50.
#
# ============================================================
# ResNet Results
# ============================================================
# Set        MSE          RMSE       MAE        R²
# ------------------------------------------------------------
# Train      79.4468      8.9133     6.2050     0.3365
# Val        79.8891      8.9381     6.2268     0.3342
# Test       78.2014      8.8432     6.1988     0.3320

# %% [markdown]
# ## 8. Model Comparison

# %%
comparison_data = []
for model_name, results in all_results.items():
    comparison_data.append({
        'Model': model_name,
        'Train RMSE': results['train_rmse'],
        'Val RMSE': results['val_rmse'],
        'Test RMSE': results['test_rmse'],
        'Test MAE': results['test_mae'],
        'Test R²': results['test_r2'],
        'Epochs': results['epochs'],
        'Train Time (s)': results['train_time']
    })

comparison_df = pd.DataFrame(comparison_data).sort_values('Test RMSE')
print("\nDeep Learning Model Comparison (sorted by Test RMSE):")
print(comparison_df.to_string(index=False))
# Out:
# Deep Learning Model Comparison (sorted by Test RMSE):
#         Model  Train RMSE  Val RMSE  Test RMSE  Test MAE  Test R²  Epochs  Train Time (s)
#    Simple MLP    8.379099  8.779502   8.706170  6.048491 0.352527     100      379.267989
#        ResNet    8.913293  8.938068   8.843155  6.198777 0.331992      65      657.129309
#       Deep NN   10.451291 10.716557  10.326526  7.348140 0.089089      87      784.777441
# Wide and Deep   10.434154 10.462043  10.390202  8.498646 0.077821      32      219.750270

# %%
fig = px.bar(
    comparison_df,
    x='Model',
    y=['Train RMSE', 'Val RMSE', 'Test RMSE'],
    barmode='group',
    title='Deep Learning Model Comparison - RMSE',
    labels={'value': 'RMSE (years)', 'variable': 'Dataset'}
)
fig.update_layout(template='plotly_white')
fig.write_html('reports/figures/29_dl_model_comparison.html')
fig.show()

# %%
fig = px.bar(
    comparison_df,
    x='Model',
    y='Test R²',
    title='Deep Learning Model Comparison - R² Score',
    color='Test R²',
    color_continuous_scale='Viridis'
)
fig.update_layout(template='plotly_white')
fig.write_html('reports/figures/30_dl_model_r2.html')
fig.show()

# %% [markdown]
# ## 9. Best Model Predictions

# %%
best_model_name = comparison_df.iloc[0]['Model']
print(f"Best DL Model: {best_model_name}")

if best_model_name == 'Simple MLP':
    best_model = simple_mlp
elif best_model_name == 'Deep NN':
    best_model = deep_nn
elif best_model_name == 'Wide and Deep':
    best_model = wide_deep
else:
    best_model = resnet
# Out:
# Best DL Model: Simple MLP

# %%
y_test_pred = best_model.predict(X_test, verbose=0).flatten()

sample_size = 5000
sample_idx = np.random.choice(len(y_test), sample_size, replace=False)

fig = px.scatter(
    x=y_test[sample_idx],
    y=y_test_pred[sample_idx],
    title=f'{best_model_name} - Predicted vs Actual Year',
    labels={'x': 'Actual Year', 'y': 'Predicted Year'},
    opacity=0.5
)

min_val = min(y_test.min(), y_test_pred.min())
max_val = max(y_test.max(), y_test_pred.max())
fig.add_trace(go.Scatter(
    x=[min_val, max_val],
    y=[min_val, max_val],
    mode='lines',
    name='Perfect Prediction',
    line=dict(color='red', dash='dash')
))

fig.update_layout(template='plotly_white')
fig.write_html('reports/figures/31_best_dl_predictions.html')
fig.show()

# %%
residuals = y_test - y_test_pred

fig = px.histogram(
    x=residuals,
    nbins=100,
    title=f'{best_model_name} - Residual Distribution',
    labels={'x': 'Residual (Actual - Predicted)', 'y': 'Frequency'}
)
fig.add_vline(x=0, line_dash='dash', line_color='red')
fig.update_layout(template='plotly_white')
fig.write_html('reports/figures/32_best_dl_residuals.html')
fig.show()

print(f"\nResidual Statistics:")
print(f"Mean: {residuals.mean():.4f}")
print(f"Std: {residuals.std():.4f}")
# Out:
# Residual Statistics:
# Mean: 0.0693
# Std: 8.7059

# %% [markdown]
# ## 10. Save Results

# %%
simple_mlp.save('models/dl/simple_mlp_final.keras')
deep_nn.save('models/dl/deep_nn_final.keras')
wide_deep.save('models/dl/wide_deep_final.keras')
resnet.save('models/dl/resnet_final.keras')

print("All models saved to models/dl/")
# Out:
# All models saved to models/dl/

# %%
comparison_df.to_csv('reports/metrics/05_dl_model_comparison.csv', index=False)
print("Model comparison saved to reports/metrics/05_dl_model_comparison.csv")
# Out:
# Model comparison saved to reports/metrics/05_dl_model_comparison.csv

# %%
best_model_info = {
    'model_name': best_model_name,
    'test_rmse': float(comparison_df.iloc[0]['Test RMSE']),
    'test_mae': float(comparison_df.iloc[0]['Test MAE']),
    'test_r2': float(comparison_df.iloc[0]['Test R²'])
}

with open('reports/metrics/best_dl_model.json', 'w') as f:
    json.dump(best_model_info, f, indent=2)

print(f"\nBest DL Model: {best_model_name}")
print(f"Test RMSE: {best_model_info['test_rmse']:.4f} years")
print(f"Test MAE: {best_model_info['test_mae']:.4f} years")
print(f"Test R²: {best_model_info['test_r2']:.4f}")
# Out:
# Best DL Model: Simple MLP
# Test RMSE: 8.7062 years
# Test MAE: 6.0485 years
# Test R²: 0.3525
